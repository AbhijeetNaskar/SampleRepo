# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["Aakash", "Rishi", "Ravi", "Dev"],
    "marks":[86, 70, 95, 80],
    "place":["United Kindgom", "India", "USA", "Singapore"]
}

# %%
pd.DataFrame(dict1)
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore

# %%
df = pd.DataFrame(dict1)

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends_NoIndex.csv", index=False)

# %%
df.head(2)
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India

# %%
df.tail(2)
# Out:
#    name  marks      place
# 2  Ravi     95        USA
# 3   Dev     80  Singapore

# %%
df.describe()
# Out:
#        marks
# count   4.00
# mean   82.75
# std    10.50
# min    70.00
# 25%    77.50
# 50%    83.00
# 75%    88.25
# max    95.00

# %% [markdown]
# ** describe the mathematical stats for number column

# %%
frnList = pd.read_csv("CountryList.csv")

# %% [markdown]
# **Using Panda to read from CSV

# %%
frnList
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList["name"][0]
# Out:
# 'Aakash'

# %%
frnList.sort_index(axis=0, ascending=False)
# Out:
#      name  marks           place
# 6   Atanu     60          Mumbai
# 5    Puru     30       Bangalore
# 4   Rahul     50      Hong Kong
# 3     Dev     80       Singapore
# 2    Ravi     95             USA
# 1   Rishi     70           India
# 0  Aakash     86  United Kindgom

# %%
frnList.sort_index(axis=1, ascending=False)
# Out:
#             place    name  marks
# 0  United Kindgom  Aakash     86
# 1           India   Rishi     70
# 2             USA    Ravi     95
# 3       Singapore     Dev     80
# 4      Hong Kong    Rahul     50
# 5       Bangalore    Puru     30
# 6          Mumbai   Atanu     60

# %%
frnList["place"]
# Out:
# 0    United Kindgom
# 1             India
# 2               USA
# 3         Singapore
# 4        Hong Kong
# 5         Bangalore
# 6            Mumbai
# Name: place, dtype: object

# %%
frnList1 = frnList.copy()

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList.loc[(frnList["marks"]>50) & (frnList["place"]=="USA")]
# Out:
#    name  marks place
# 2  Ravi     95   USA

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList1.drop([5])
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 6   Atanu     60          Mumbai

# %%
frnList
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList1=frnList1.drop([5])

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 6   Atanu     60          Mumbai

# %%
frnList
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5    Puru     30       Bangalore
# 6   Atanu     60          Mumbai

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 6   Atanu     60          Mumbai

# %%
frnList1.drop(["place", "marks"], axis=1)
# Out:
#      name
# 0  Aakash
# 1   Rishi
# 2    Ravi
# 3     Dev
# 4   Rahul
# 6   Atanu

# %%
frnList1
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 6   Atanu     60          Mumbai

# %%
frnList1.reset_index()
# Out:
#    index    name  marks           place
# 0      0  Aakash     86  United Kindgom
# 1      1   Rishi     70           India
# 2      2    Ravi     95             USA
# 3      3     Dev     80       Singapore
# 4      4   Rahul     50      Hong Kong
# 5      6   Atanu     60          Mumbai

# %%
frnList1.reset_index(drop=True)
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 5   Atanu     60          Mumbai

# %% [markdown]
# frnList1.reset_index(drop=True, inplace=True) -- to update the main table

# %% [markdown]
# How to drop the duplicate
# frnList1.drop_duplicates(subset=["name"])

# %%
frnList1.drop_duplicates()
# Out:
#      name  marks           place
# 0  Aakash     86  United Kindgom
# 1   Rishi     70           India
# 2    Ravi     95             USA
# 3     Dev     80       Singapore
# 4   Rahul     50      Hong Kong
# 6   Atanu     60          Mumbai

# %%
frnList1.shape
# Out:
# (6, 3)

# %%
frnList1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   marks   6 non-null      int64
#  2   place   6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 192.0+ bytes

# %%
frnList["marks"].value_counts()
# Out:
# marks
# 86    1
# 70    1
# 95    1
# 80    1
# 50    1
# 30    1
# 60    1
# Name: count, dtype: int64

# %% [markdown]
# * to read from excel using panda, install xlrd
# * pip install xlrd
# * To write on excel using panda, install openpyxl
# * pip install openpyxl
